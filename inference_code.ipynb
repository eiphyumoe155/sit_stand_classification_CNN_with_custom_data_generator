# %% [markdown]
# # Testing Image

# %%
import tensorflow as tf
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Sit_Stand/cnn_model_with_custom_gen (1).h5')

# %%
categories = ['Negative','Sit','Stand']

# %%
# predicting images
img = tf.keras.utils.load_img('/content/drive/MyDrive/Sit_Stand/train/sit/DS_006_002_003_001_000046.jpg', target_size=(224, 128))
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x/255
plt.imshow(x[0])
classes = model.predict(x)
classes = np.argmax(classes,axis=1)
print ('Class:', categories[int(classes)])
print (classes)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Class: Sit
# [1]
